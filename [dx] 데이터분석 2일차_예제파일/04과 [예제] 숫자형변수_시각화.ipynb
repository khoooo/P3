# %% [markdown]
# # 04과 [예제] 숫자형변수_시각화

# %% [markdown]
# * [4-1] 히스토그램

# %%
# 0) 라이브러리 로딩
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------------------------
# 1) 히스토그램 기본

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# plt.hist(age, bins = 5, edgecolor = 'gray')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# # plt.savefig('a')
# plt.show()
# ----------------------------------------------
# 2) 구간의 갯수를 조정해 봅시다.

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# plt.hist(age, bins = 10, edgecolor = 'gray')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# # plt.savefig('a')
# plt.show()
# ----------------------------------------------
# 3) 구간 값과 갯수를 확인해 봅시다.

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# hist1 = plt.hist(age, bins = 5, edgecolor = 'gray')

# print(hist1)
# print(type(hist1))
# print('-' * 50)
# print('빈도수 : ', hist1[0])
# print('구간값 : ', hist1[1])

# ----------------------------------------------
# 4) 연습문제를 풀어 봅시다.
import pandas as pd
data = pd.read_csv("https://bit.ly/3HaMAtZ", usecols = ['Age','Fare'])
# 필요 칼럼만 지정


# Age에 칼럼에 대해 히스토그램을 그려 봅시다.
# bins = 8, 16, 32, 64

# a = [0, 8, 16, 32, 64, data['Age'].max()]
plt.hist(data['Age'], bins=64, edgecolor = 'grey')
plt.show()


# Age에 칼럼에 대해 히스토그램을 그릴때, 
# 빈도수와 구간값을 살펴 봅시다.
# bins = 8

hist1 = plt.hist(data['Age'], bins=8, edgecolor='grey')
print('빈도수 :',hist1[0])
print('구간값 :',hist1[1])
print(hist1[2])
# Out:
# 빈도수 : [ 68. 115. 266. 291.  87.  42.  17.   5.]
# 구간값 : [ 0.42   10.3675 20.315  30.2625 40.21   50.1575 60.105  70.0525 80.    ]
# <BarContainer object of 8 artists>

# %% [markdown]
# * [4-2] 밀도함수 그래프

# %%
# 0) 라이브러리 로딩

import matplotlib.pyplot as plt
import pandas as pd

# ----------------------------------------------
# 1) 밀도함수 그래프.

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# age = pd.Series(age)
# age.plot(kind = 'kde')

# plt.show()

# ----------------------------------------------
# 2) 연습문제

age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]

# 히스토그램을 그리시오.
plt.hist(age, bins=64, edgecolor='grey')
plt.show()

# 밀도함수 그래프를 그리시오.
age1 = pd.Series(age)
age1.plot(kind='kde')
plt.show()
# 두 그래프는 어떤 차이가 있나요?

# 그래프의 연속, 불연속 차이
# 데이터 개수와 확률 차이
# 시각적 표현 차이

# %%
# 추가.

print(data.head(3))
print('\n')
# 기초 통계량
print(data['Fare'].describe())

# hist
plt.hist(data['Fare'], bins=50, edgecolor='grey')
plt.show()

# density plot
data['Fare'].plot(kind='kde')
plt.show()

# 최대치 유무를 따지기 힘들다
# Out:
#     Age     Fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
#
#
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# * [4-3] boxplot

# %%
# 0) 라이브러리 로딩

import matplotlib.pyplot as plt

# ----------------------------------------------

# 1) boxplot 기본

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# plt.boxplot(age)
# # plt.savefig('a.png')
# plt.show()

# ----------------------------------------------
# 2) 옆으로 그리기

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# plt.boxplot(age, vert = False)
# plt.savefig('a.png')

# ----------------------------------------------
# 3) 박스플로의 값들 가져오기

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# box1 = plt.boxplot(age)

# print(type(box1))
# print(box1.keys())
# print('-'* 50)
# print(box1['whiskers'])
# print(box1['whiskers'][0].get_ydata()) # 아래쪽 수염의 max, min
# print(box1['whiskers'][1].get_ydata()) # 위쪽 수염의 min, max

# ----------------------------------------------
# 4) 연습문제를 풀어 봅시다.
import pandas as pd
data = pd.read_csv("https://bit.ly/3HaMAtZ", usecols = ['Age','Fare'])
# Age에 칼럼에 대해 

# 박스 플롯을 그려 봅시다.
plt.boxplot(data['Age'])
plt.show()

# 박스 플롯을 옆으로 그려 봅시다.
plt.boxplot(data['Age'], vert=False)
plt.show()

# 박스 플롯의 아래 수염의 min, max, 윗 수염의 min, max
box = plt.boxplot(data['Age'])
print(box['whiskers'][0].get_ydata())
print(box['whiskers'][1].get_ydata())
# Out:
# [21.77  0.67]
# [35.9 57. ]

# %% [markdown]
# * [4-4] 바이올린 플롯

# %%
# 0) 라이브러리 로딩

import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------
# 1) 바이올린 플롯 그리기

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
# age_m = np.mean(age)

# plt.violinplot(age, vert = False, showmeans=True)
# plt.text( age_m - 1, 0.85 , age_m)
# # plt.savefig('a.png')
# plt.show()
# --------------------------------------------------
# 2) 4가지 플롯을 한꺼번에 그려 봅시다.

# age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]

# plt.subplot(2,2,1)
# plt.hist(age, bins = 8, edgecolor = 'grey')

# plt.subplot(2,2,2)
# plt.boxplot(age, vert = False)

# plt.subplot(2,2,3)
# pd.Series(age).plot(kind = 'kde')

# plt.subplot(2,2,4)
# plt.violinplot(age, vert = False, showmeans=True)

# # plt.savefig('a.png')
# plt.show()

# --------------------------------------------------
# 3) 연습문제를 풀어 봅시다.

import pandas as pd
data = pd.read_csv("https://bit.ly/3HaMAtZ", usecols = ['Age','Fare'])
# Age에 칼럼에 대해 

# 바이올린 플롯을 그려봅시다.
# 평균 값도 포함시켜 봅시다.
# plt.violinplot(data['Age'], vert=False, showmeans=True)

# plt.show()

# 4가지 플롯을 한꺼번에 그려 봅시다.

plt.subplot(2,2,1)
plt.hist(data['Fare'], bins=16, edgecolor='grey')

plt.subplot(2,2,2)
plt.boxplot(data['Fare'], vert=False)

plt.subplot(2,2,3)
data['Fare'].plot(kind='kde')

plt.subplot(2,2,4)
plt.violinplot(data['Fare'], vert=False, showmeans=True)

plt.text(50,0.85, round(data['Fare'].mean(),2) )
plt.show()

# --------------------------------------------------
# 4) 시계열 데이터 시각화
# import pandas as pd

# air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv ')
# air['Date'] = pd.to_datetime(air['Date']) # 날짜 형식으로 변환

# plt.plot('Date', 'Ozone', 'g-', data = air, label = 'Ozone')
# plt.plot('Date', 'Temp', 'r-', data = air, label = 'Temp')

# plt.xlabel('Date')
# plt.legend()
# plt.savefig('a.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv ')
air['Date'] = pd.to_datetime(air['Date']) # 날짜 형식으로 변환

plt.plot('Date', 'Ozone', 'g-', data = air, label = 'Ozone')
plt.plot('Date', 'Temp', 'r-', data = air, label = 'Temp')

plt.xlabel('Date')
plt.legend()
# plt.savefig('a.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.1.csv')

plt.subplot(2,2,1)
plt.hist(titanic['Age'], bins = 16, edgecolor = 'grey')

plt.subplot(2,2,2)
plt.boxplot(titanic['Age'], vert = False)

plt.subplot(2,2,3)
titanic['Age'].plot(kind = 'kde')

plt.subplot(2,2,4)
plt.violinplot(titanic['Age'], vert = False, showmeans=True)

plt.savefig('a.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.1.csv')

plt.figure(figsize = (8,6))
plt.subplot(2,1,1)
plt.hist(titanic['Age'], bins = 16, edgecolor = 'grey')

plt.subplot(2,1,2)
plt.boxplot(titanic['Age'], vert = False)
plt.savefig('a.png')
